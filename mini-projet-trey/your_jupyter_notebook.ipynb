# %%
import pandapower as pp

# %%
rtszthfg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rtszthfg
#
# NameError: name 'rtszthfg' is not defined

# %%
pip list | grep pandapower
sldkfj
# Out:
#   Cell In[2], line 1
#     pip list | grep pandapower
#         ^
# SyntaxError: invalid syntax

# %%
pp.from_json(
    "/home/thierryfra/github/pro/rhtlab_test_windows/mini-projet-trey/input-data/trey_net_student.json"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pp.from_json(
#       2     "/home/thierryfra/github/pro/rhtlab_test_windows/mini-projet-trey/input-data/trey_net_student.json"
#       3 )
#
# File ~/github/pro/rhtlab_test_windows/.venv/lib/python3.12/site-packages/pandapower/file_io.py:280, in from_json(filename_or_str, convert, encryption_key, elements_to_deserialize, keep_serialized_elements, add_basic_std_types, replace_elements, empty_dict_like_object, ignore_unknown_objects)
#     278     json_string = filename_or_str
#     279 try:
# --> 280     return from_json_string(
#     281         json_string,
#     282         convert=convert,
#     283         encryption_key=encryption_key,
#     284         elements_to_deserialize=elements_to_deserialize,
#     285         keep_serialized_elements=keep_serialized_elements,
# ...

# %%
pp.from_pickle(
    "/home/thierryfra/github/pro/rhtlab_test_windows/mini-projet-trey/input-data/trey_net_student_v2.p"
)
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (13 elements)
#    - load (12 elements)
#    - ext_grid (1 element)
#    - line (11 elements)
#    - trafo (1 element)

# %%
pp.from_pickle(
    "/home/thierryfra/github/pro/rhtlab_test_windows/mini-projet-trey/input-data/trey_net_cplt.p"
)
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (13 elements)
#    - load (12 elements)
#    - sgen (3 elements)
#    - ext_grid (1 element)
#    - line (11 elements)
#    - trafo (1 element)
#    - controller (4 elements)
#    - time_index (96 elements)
#    - output_writer (1 element)
#  and the following results tables:
#    - res_bus (13 elements)
#    - res_line (11 elements)
#    - res_trafo (1 element)
#    - res_ext_grid (1 element)
#    - res_load (12 elements)
#    - res_sgen (3 elements)
